# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
# /\ Makes jupyter find local modules ;D

# %%
from neuralnetwork.perceptron import Perceptron
perceptron = Perceptron([0,0]) # o input era só pra ser o tamanho =X
print(perceptron.weights)
print(perceptron.bias)
# Out:
# [0.8498583338347807, 0.0034017273798371273]
# 1

# %%
# Test 1
perceptron.predict([0,0])
# Out:
# 1

# %%
# Test 2
"""
wait for it...





































No Spoiler ;D
"""
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNo Spoiler ;D\n'

# %%
from neuralnetwork.perceptron import Trainer
from neuralnetwork.dataset import OR_DATASET, AND_DATASET, FIVE_OR_MORE_DATASET
from util.plot import scatter_2d

# %matplotlib inline 
# open plotted inside jupyter

# %%
trainer = Trainer(AND_DATASET, perceptron)
trainer.analyze()
# Out:
# [Analyzing]
# expected: 0 got:1
# expected: 0 got:1
# expected: 0 got:1
# expected: 1 got:1
# Perceptron weights: [0.8498583338347807, 0.0034017273798371273]
# Perceptron bias: 1
# Error: 0.75

# %%
scatter_2d(AND_DATASET)

# %%
trainer.train_times(100)

# %%
trainer.analyze()
# Out:
# [Analyzing]
# expected: 0 got:0
# expected: 0 got:0
# expected: 0 got:0
# expected: 1 got:1
# Perceptron weights: [0.3498583338347808, 0.10340172737983713]
# Perceptron bias: 0.10000000000000014
# Error: 0.0

# %%
"""










=O
"""

# %%
from util.plot import scatter_3d
scatter_3d(FIVE_OR_MORE_DATASET)
# Out:
# > /home/ramon/code/ramon/neural-network-study/util/plot.py(33)scatter_value_color()
# ->
# (Pdb) c
# > /home/ramon/code/ramon/neural-network-study/util/plot.py(33)scatter_value_color()
# ->
# (Pdb) c

# %%
perceptron = Perceptron([0,0,0])
trainer = Trainer(FIVE_OR_MORE_DATASET, perceptron)
# O perceptron consegue separar esses grupos?

# %%
trainer.analyze()
# Out:
# [Analyzing]
# expected: 0 got:1
# expected: 0 got:1
# expected: 0 got:1
# expected: 0 got:1
# expected: 0 got:1
# expected: 1 got:1
# expected: 1 got:1
# expected: 1 got:1
# Perceptron weights: [0.6629535738908312, 0.2551181873778726, 0.3751696177340357]
# Perceptron bias: 1
# Error: 0.625

# %%
trainer.train_times(100)

# %%
trainer.analyze()
# Out:
# [Analyzing]
# expected: 0 got:0
# expected: 0 got:0
# expected: 0 got:0
# expected: 0 got:0
# expected: 0 got:0
# expected: 1 got:1
# expected: 1 got:1
# expected: 1 got:1
# Perceptron weights: [0.36295357389083127, 0.05511818737787261, 0.07516961773403569]
# Perceptron bias: 0.10000000000000014
# Error: 0.0

# %%
"""








E agora?
"""
from neuralnetwor.dataset import XOR_DATASET
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-61-244f233a540e> in <module>
#      10 E agora?
#      11 """
# ---> 12 from neuralnetwor.dataset import XOR_DATASET
#
# ModuleNotFoundError: No module named 'neuralnetwor'
